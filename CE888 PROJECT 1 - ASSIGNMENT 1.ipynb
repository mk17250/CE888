# %% [markdown]
# ## PROJECT ONE - IMAGE CLASSIFICATION: FIRE VS NO FIRE

# %%
#### import libraries 
import os
import numpy as np
import pandas as pd
import random
import pickle
import itertools
import matplotlib.pyplot as plt
import tensorflow as tf
import keras as ke
from skimage.io import imshow
import glob
from PIL import Image

# %%
list_test_fire = []
for filename in glob.glob("C:/Users/Home/OneDrive/CE888/Test/Fire/*.jpg"): 
    im=Image.open(filename)
    list_test_fire.append(im)

# %%
list_test_fire
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=254x254 at 0x1E1941085E0>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=254x254 at 0x1E19CB08BE0>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=254x254 at 0x1E19CB08B80>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=254x254 at 0x1E19CB08AF0>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=254x254 at 0x1E19CB08A90>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=254x254 at 0x1E19CB089D0>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=254x254 at 0x1E19CB08910>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=254x254 at 0x1E19CB08880>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=254x254 at 0x1E19CB08820>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=254x254 at 0x1E19CB08790>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=254x254 at 0x1E19CB08760>,
# ...

# %%
plt.imshow(list_test_fire[50])

# %%
len(list_test_fire)
# Out:
# 5137

# %%
type(list_test_fire)
# Out:
# list

# %%
list_test_nofire = []
for filename in glob.iglob("C:/Users/Home/OneDrive/CE888/Test/No_Fire/*"): 
    im=Image.open(filename)
    list_test_nofire.append(im)

# %%
test_nofire_arr = []
for f in glob.iglob("C:/Users/Home/OneDrive/CE888/Test/No_Fire/*"):
    test_nofire_arr.append(np.asarray(Image.open(f)))
    
    images = np.array(images)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-789dfcc81a1e> in <module>
#       1 test_nofire_arr = []
#       2 for f in glob.iglob("C:/Users/Home/OneDrive/CE888/Test/No_Fire/*"):
# ----> 3     test_nofire_arr.append(np.asarray(Image.open(f)))
#       4
#       5     images = np.array(images)
#
# ~\anaconda3\envs\tf\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#
# OSError: [Errno 24] Too many open files: 'C:/Users/Home/OneDrive/CE888/Test/No_Fire\\resized_test_nofire_frame0.jpg'

# %%
list_train_fire = []
for filename in glob.iglob("C:/Users/Home/OneDrive/CE888/Training/Fire/*"): 
    im=Image.open(filename)
    list_train_fire.append(im)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-ca7ef2c35f6a> in <module>
#       1 list_train_fire = []
#       2 for filename in glob.iglob("C:/Users/Home/OneDrive/CE888/Training/Fire/*"):
# ----> 3     im=Image.open(filename)
#       4     list_train_fire.append(im)
#
# ~\anaconda3\envs\tf\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#
# OSError: [Errno 24] Too many open files: 'C:/Users/Home/OneDrive/CE888/Training/Fire\\resized_frame14594.jpg'

# %%
list_train_nofire = []
for filename in glob.iglob("C:/Users/Home/OneDrive/CE888/Training/No_Fire/*"): 
    im=Image.open(filename)
    list_train_nofire.append(im)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-11-593a5f4baeb6> in <module>
#       1 list_train_nofire = []
#       2 for filename in glob.iglob("C:/Users/Home/OneDrive/CE888/Training/No_Fire/*"):
# ----> 3     im=Image.open(filename)
#       4     list_train_nofire.append(im)
#
# ~\anaconda3\envs\tf\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#
# OSError: [Errno 24] Too many open files: 'C:/Users/Home/OneDrive/CE888/Training/No_Fire\\lake_resized_lake_frame0.jpg'
